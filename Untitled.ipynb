# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

# Load data
data = pd.read_csv(r"C:\Users\Dell\Downloads\AIML\ML/archiveemail/email.csv")
Category = data['Category']
Message = data['Message']

# Convert labels (spam/ham) to numbers (1/0)
encoder = LabelEncoder()
y = encoder.fit_transform(Category)

# Vectorize the email messages
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(Message)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Train the model
model = LogisticRegression()
model.fit(X_train, y_train)

# Predict and evaluate
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

# Predict new email
new_email = ["Congratulations! You have won a free prize. Click here to claim now"]
new_features = vectorizer.transform(new_email)
prediction = model.predict(new_features)
print(f'{new_email} is Spam'if prediction[0] == 1 else "Not Spam")
# Out:
# Accuracy: 0.9835007173601148
# ['Congratulations! You have won a free prize. Click here to claim now'] is Spam
